# %%
from flask import Flask, render_template, request
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\arvin\\MLProjectsFolder\\RoadSeg\\FlaskApp'

# %%
app = Flask(__name__)
UPLOAD_FOLDER = 'uploads'
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER

# %%
@app.route('/')
def home():
    return render_template('index.html')

# @app.route('/predict', methods = ['POST'])
# def predict():
#     return jsonify({})

@app.route('/upload', methods = ['POST'])
def upload():
    if(request.method == 'POST'):
        file = request.files['file']
        if file:
            filename = file.filename
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], filename))
            return f'<h1>Uploaded: {filename}</h1><img src="outputs/alena-aenami-darknight2200.jpg" alt="Output image">'
        return "No file uploaded"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 @app.route('/')
#       2 def home():
#       3     return render_template('index.html')
#       5 # @app.route('/predict', methods = ['POST'])
#       6 # def predict():
#       7 #     return jsonify({})
#
# File ~\anaconda3\Lib\site-packages\flask\scaffold.py:435, in Scaffold.route.<locals>.decorator(f)
#     433 def decorator(f: t.Callable) -> t.Callable:
#     434     endpoint = options.pop("endpoint", None)
# --> 435     self.add_url_rule(rule, endpoint, f, **options)
#     436     return f
#
# File ~\anaconda3\Lib\site-packages\flask\scaffold.py:56, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 if self._is_setup_finished():
#      46     raise AssertionError(
#      47         "A setup function was called after the first request "
#      48         "was handled. This usually indicates a bug in the"
#    (...)
#      54         " requests."
#      55     )
# ---> 56 return f(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\flask\app.py:1092, in Flask.add_url_rule(self, rule, endpoint, view_func, provide_automatic_options, **options)
#    1090 old_func = self.view_functions.get(endpoint)
#    1091 if old_func is not None and old_func != view_func:
# -> 1092     raise AssertionError(
#    1093         "View function mapping is overwriting an existing"
#    1094         f" endpoint function: {endpoint}"
#    1095     )
#    1096 self.view_functions[endpoint] = view_func
#
# AssertionError: View function mapping is overwriting an existing endpoint function: home

# %%
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# [2024-05-07 19:15:27,100] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\app.py", line 2070, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\app.py", line 1515, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\app.py", line 1513, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\app.py", line 1499, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\AppData\Local\Temp\ipykernel_8884\83662868.py", line 3, in home
#     return render_template('MLProjectsFolder/RoadSeg/FlaskApp/index.html')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\arvin\anaconda3\Lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: MLProjectsFolder/RoadSeg/FlaskApp/index.html
# 127.0.0.1 - - [07/May/2024 19:15:27] "GET / HTTP/1.1" 500 -
